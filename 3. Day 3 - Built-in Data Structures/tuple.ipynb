# %%
# Length and type

t = (1,2,3,4,5,6)
print(len(t))
print(type(t))
# Out:
# 6
# <class 'tuple'>

# %%
# min, max and sum

t = (1,2,3,4,5,6)
print(min(t))
print(max(t))
print(sum(t))
# Out:
# 1
# 6
# 21

# %%
# Indexing and Slicing from the tuple

print(t[2])
print(t[-3])
print(t[1:4])
print(t[-4:-1])
# Out:
# 3
# 4
# (2, 3, 4)
# (3, 4, 5)

# %%
# Count and Index

p = (1,2,3,4,2,3,4,5,2,3,4,2,3,1,3,2)
print(p.count(7))
print(p.index(2,2,-1))
print(p.index(7))
# Out:
# 0
# 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 6
#       4 print(p.count(7))
#       5 print(p.index(2,2,-1))
# ----> 6 print(p.index(7))
#
# ValueError: tuple.index(x): x not in tuple
